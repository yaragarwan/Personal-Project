# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Basics of plotting:
x = [1,2,4,6]
y = [2,6,7,8]
z = [3,5,7,4]
plt.title("testing")
plt.xlabel("x-axis")
plt.ylabel("y-axis and z-axis")
plt.plot(x,y)
plt.plot(x,z)
plt.legend(["y-axis", "z-axis"])
plt.show()

# %%
# How to laod data from a csv file:
sampledata= pd.read_csv("sample_data.csv") # data is loaded into the notebook

# %%
sampledata
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sampledata)
# Out:
# pandas.core.frame.DataFrame

# %%
sampledata.column_c # to retrieve a single column
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sampledata.column_c)
# Out:
# pandas.core.series.Series

# %%
sampledata.column_c.iloc[1] # to show the value of the series in index 1
# Out:
# 8

# %%
# plot the dataframe using column A as the x-axis and column B as the y-axis:
plt.plot(sampledata.column_a, sampledata.column_b, "o")
plt.plot(sampledata.column_a, sampledata.column_c)
plt.legend(["Column B", "column C"])
plt.title("Sample Data")
plt.xlabel("Column A")
plt.ylabel("Column B & C")
plt.show()

# %%
thedata = pd.read_csv("countries.csv")

# %%
thedata
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
# The analysis we wanna do is we wanna compare the population growth in the US and china
# first isolate the data for US and China

# %%
us = thedata[thedata.country=="United States"]

# %%
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china = thedata[thedata.country=="China"]

# %%
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
# first plot the us population 
plt.plot(us.year, us.population / 10** 6)
plt.show()

# %%
# Chian plot
plt.plot(china.year, china.population / 10 **6)
plt.show()

# %%
# plot china plot on top of us plot:
plt.plot(us.year, us.population / 10** 6)
plt.xlabel("Year")
plt.ylabel("Population in mill.")
plt.plot(china.year, china.population / 10 **6)
plt.legend(["US", "China"])
plt.show()

# %%
saudi = thedata[thedata.country=="Saudi Arabia"]

# %%
plt.plot(saudi.year, saudi.population / 10**6)
plt.plot (china.year, china.population / 10**6)
plt.plot(us.year, us.population / 10** 6)
plt.legend(["Saudi", "china", "US"])
plt.show()
